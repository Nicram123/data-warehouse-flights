# %% [markdown]
# ### Przed wprowadzeniem zmian

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_silver.dim_airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>14</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM flight_sales_silver.dim_airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_silver.dim_airports
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>322</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM flight_sales_silver.dim_airports
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql 
SELECT COUNT(*) FROM flight_sales_gold.fact_flights -- 5818795
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5818795</td></tr></tbody></table></div>

# %% [markdown]
# ### Po wprowadzonych zmianach

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_silver.dim_airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>16</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM flight_sales_silver.dim_airlines
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_silver.dim_airports
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>325</td></tr></tbody></table></div>

# %%
# %sql
SELECT * FROM flight_sales_silver.dim_airports
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql 
SELECT COUNT(*) FROM flight_sales_gold.fact_flights -- 5818795
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5818795</td></tr></tbody></table></div>

# %% [markdown]
# - przed INSERT

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_gold.fact_flights -- 5818795
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5818795</td></tr></tbody></table></div>

# %% [markdown]
# - przed UPDATE

# %%
# %sql 
SELECT * 
FROM flight_sales_gold.fact_flights 
JOIN flight_sales_silver.dim_aircraft da 
ON flight_sales_gold.fact_flights.aircraft_key = da.aircraft_key 
WHERE airline_key = 'MQ' AND flight_number = 2916 AND da.tail_number = 'N539MQ' AND flight_id=1048499;
-- 5818795
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# - po update

# %% [markdown]
# - scheduled_arrival_minutes się zmienia na 975 (minuty od północy)

# %%
# %sql 
SELECT * 
FROM flight_sales_gold.fact_flights 
JOIN flight_sales_silver.dim_aircraft da 
ON flight_sales_gold.fact_flights.aircraft_key = da.aircraft_key 
WHERE airline_key = 'MQ' AND flight_number = 2916 AND da.tail_number = 'N539MQ' AND flight_id=1048499;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# - po INSERT

# %%
# %sql
SELECT COUNT(*) FROM flight_sales_gold.fact_flights -- 5818795
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>5818796</td></tr></tbody></table></div>

# %%
# %sql
SELECT da.airline_key, da.airline_name FROM flight_sales_gold.fact_flights
JOIN flight_sales_silver.dim_airlines da 
ON flight_sales_gold.fact_flights.airline_key = da.airline_key 
WHERE da.airline_key = 'XD'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>airline_key</th><th>airline_name</th></tr></thead><tbody><tr><td>XD</td><td>NAME</td></tr></tbody></table></div>
