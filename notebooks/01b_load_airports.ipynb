# %%
import schemas
airports_df = (
    spark.read.format("csv")
    .option("header", "true")
    .schema(schemas.airports_schema)
    .load("/Volumes/workspace/flight_schema/flight_volume/airports.csv")
)

airports_df.write.format("delta").mode("overwrite").saveAsTable("flight_sales_bronze.bronze_airports_raw")

# %%
# %sql 
SELECT * FROM flight_sales_bronze.bronze_airports_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT COUNT(IATA_CODE) - COUNT(DISTINCT IATA_CODE) AS liczba_duplikatow
FROM flight_sales_bronze.bronze_airports_raw;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>liczba_duplikatow</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>
