# %%
import schemas 
airlines_df = (
    spark.read.format("csv")
    .option("header", "true")
    .schema(schemas.airlines_schema)
    .load("/Volumes/workspace/flight_schema/flight_volume/airlines.csv")
)
airlines_df.write.format("delta").mode("overwrite").saveAsTable("flight_sales_bronze.bronze_airlines_raw")

# %%
# %sql 
SELECT * FROM flight_sales_bronze.bronze_airlines_raw
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
